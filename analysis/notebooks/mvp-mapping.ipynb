# %% [markdown]
# Overall strategy:
#
# - two approaches then merge
#   - composite term mapping:
#     - first try whole term mapping
#       -> then for unmapped, try word ngram mapping
#   - equivalent term mapping
#     - query the whole term with scispacy embedding

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
from typing import Any, Dict, List
from pprint import pprint

import pandas as pd
import numpy as np
import janitor
import spacy
import requests
from pydash import py_
from Levenshtein import distance as levenshtein_distance
from tqdm import tqdm

from funcs import utils, query, paths, settings

# %%
model_path = paths.models["scispacy_lg"]
assert model_path.exists(), model_path
scispacy_model = spacy.load(model_path)

# %%
proj_root = utils.find_project_root("docker-compose.yml")

data_path = proj_root / "data" / "output" / "mvp_traits_clean.json"
assert data_path.exists(), data_path

with data_path.open() as f:
    input_df = pd.json_normalize(json.load(f))

input_df.info()
input_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2079 entries, 0 to 2078
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   trait_id          2079 non-null   object
#  1   trait_term        2079 non-null   object
#  2   phenotype         2079 non-null   object
#  3   dataset           2079 non-null   object
#  4   trait_type        2079 non-null   object
#  5   trait_term_query  2079 non-null   object
# dtypes: object(6)
# memory usage: 97.6+ KB
#                         trait_id                                trait_term  \
# 0                           8-00                      Intestinal infection
# 1                          85-01                       Bacterial enteritis
# 2                         851-02                         Intestinal e.coli
# 3                         852-03  Intestinal infection due to C. difficile
# 4                          86-04                           Viral Enteritis
# ...                          ...                                       ...
# 2074      dbp-at-enrollment-2076                  Diastolic blood pressure
# 2075  p-pulse-at-enrollment-2077                                Heart rate
# 2076              height-in-2078                                    Heigth
# 2077              weight-lb-2079                                    Weight
# 2078                    bmi-2080                           Body Mass Index
#
#                     phenotype   dataset    trait_type  \
# 0                           8  UKBB+MVP       phecode
# 1                         8.5  UKBB+MVP       phecode
# 2                        8.51       MVP       phecode
# 3                        8.52  UKBB+MVP       phecode
# 4                         8.6  UKBB+MVP       phecode
# ...                       ...       ...           ...
# 2074      DBP (at enrollment)  UKBB+MVP  vital status
# 2075  P (Pulse at enrollment)  UKBB+MVP  vital status
# 2076              Height (in)       MVP  vital status
# 2077              Weight (lb)  UKBB+MVP  vital status
# 2078                      BMI  UKBB+MVP  vital status
#
#                                 trait_term_query
# 0                         [Intestinal infection]
# 1                          [Bacterial enteritis]
# 2                            [Intestinal e.coli]
# 3     [Intestinal infection due to C. difficile]
# 4                              [Viral Enteritis]
# ...                                          ...
# 2074                  [Diastolic blood pressure]
# 2075                                [Heart rate]
# 2076                                    [Heigth]
# 2077                                    [Weight]
# 2078                           [Body Mass Index]
#
# [2079 rows x 6 columns]

# %% [markdown]
# # composite term mapping

# %%
def unpick_subcomponent(term_list: List[str]) -> List[str]:
    valid = [True] * len(term_list)
    for idx, term in enumerate(term_list):
        sub_list = term_list[:idx] + term_list[(idx+1):]
        for compare_term in sub_list:
            if term.lower() in compare_term.lower() \
                and  term.lower() != compare_term.lower():
                valid[idx] = False
    res = [_ for idx, _ in enumerate(term_list) if valid[idx]]
    return res

term_list = ["bacterial enteritis", "enteritis", "body mass", "body mass index", "mass index"]
unpick_subcomponent(term_list)
# Out:
# ['bacterial enteritis', 'body mass index']

# %%
def query_composite(term_list: List[str]) -> List[Dict[str, Any]]:
    def _query(term: str): 
        es_url = settings.es_url
        index_name = "efo-vectors"
        url = f"{es_url}/{index_name}/_search"
        payload = {
            "query": {
              "match": {
                  "vector_term.raw": {
                      "query": term
                  }
              }
            },
            "_source": ["ent_id", "ent_term", "primary_term", "vector_term"],
        }
        r = requests.get(url, json=payload)
        r.raise_for_status()
        results = [_ for _ in r.json()["hits"]["hits"]]
        return results
    nested_res = [_query(_) for _ in term_list]
    flat_res = py_.chain(nested_res) \
        .flatten() \
        .uniq_by(lambda e: e["_source"]["ent_id"]) \
        .map(lambda e: e["_source"]) \
        .value()
    # when having both "body mass" and "body mass index", always favour "body mass index"
    terms = [_["vector_term"] for _ in flat_res]
    valid_terms = unpick_subcomponent(terms)
    valid_res = [_ for _ in flat_res if _["vector_term"] in valid_terms]
    return valid_res

# %%
test_terms = [
    ["Intestinal infection"],
    ["Bacterial enteritis"],
    ["Body mass index"],
    ["Tuberculosis"],
]

for idx, _ in enumerate(test_terms):
    print(f"# {idx}, {_}")
    search_res = query_composite(_)
    pprint(search_res)
    print("\n")
# Out:
# # 0, ['Intestinal infection']
# [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0005741',
#   'ent_term': 'infectious disease',
#   'primary_term': False,
#   'vector_term': 'infection'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0000544',
#   'ent_term': 'infection',
#   'primary_term': True,
#   'vector_term': 'infection'}]
#
#
# # 1, ['Bacterial enteritis']
# [{'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0000916',
#   'ent_term': 'intestinal infectious disease',
#   'primary_term': False,
#   'vector_term': 'bacterial enteritis'}]
#
#
# # 2, ['Body mass index']
# [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004340',
#   'ent_term': 'body mass index',
#   'primary_term': True,
#   'vector_term': 'body mass index'}]
#
#
# # 3, ['Tuberculosis']
# [{'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0018076',
#   'ent_term': 'tuberculosis',
#   'primary_term': True,
#   'vector_term': 'tuberculosis'},
#  {'ent_id': 'http://www.orpha.net/ORDO/Orphanet_3389',
#   'ent_term': 'Tuberculosis',
#   'primary_term': True,
#   'vector_term': 'Tuberculosis'}]

# %% [markdown]
# # equivalence term mapping

# %%
def query_equivalence_embeddings(term_list: List[str], score_threshold=0.9) -> List[Dict[str, Any]]:
    def _query(term: str): 
        es_url = settings.es_url
        index_name = "efo-vectors"
        url = f"{es_url}/{index_name}/_knn_search"
        vector = scispacy_model(term).vector.tolist()
        empty_vector = np.equal(np.sum(vector), 0)
        if empty_vector:
            return []
        payload = {
            "knn": {
                "field": "vector",
                "query_vector": vector,
                "k": 3,
                "num_candidates": 10,
            },
            "_source": ["ent_id", "ent_term", "primary_term", "vector_term"],
        }
        r = requests.get(url, json=payload)
        try:
            r.raise_for_status()
        except Exception as e:
            print(r.text)
            raise
        results = [_ for _ in r.json()["hits"]["hits"] if _["_score"] >= score_threshold]
        return results
    nested_res = [_query(_) for _ in term_list]
    res = py_.chain(nested_res) \
        .flatten() \
        .uniq_by(lambda e: e["_source"]["ent_id"]) \
        .map(lambda e: e["_source"]) \
        .value()
    return res

# %%
test_terms = [
    ["Intestinal infection"],
    ["Bacterial enteritis"],
    ["Body mass index"],
]

for idx, _ in enumerate(test_terms):
    print(f"# {idx}, {_}")
    search_res = query_equivalence_embeddings(_)
    pprint(search_res)
    print("\n")
# Out:
# # 0, ['Intestinal infection']
# []
#
#
# # 1, ['Bacterial enteritis']
# [{'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0000916',
#   'ent_term': 'intestinal infectious disease',
#   'primary_term': False,
#   'vector_term': 'bacterial enteritis'},
#  {'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0043579',
#   'ent_term': 'enteritis',
#   'primary_term': True,
#   'vector_term': 'enteritis'}]
#
#
# # 2, ['Body mass index']
# [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004340',
#   'ent_term': 'body mass index',
#   'primary_term': True,
#   'vector_term': 'body mass index'},
#  {'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0013267',
#   'ent_term': 'distal 16p11.2 microdeletion syndrome',
#   'primary_term': False,
#   'vector_term': 'body mass index QTL16'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0005851',
#   'ent_term': 'height-adjusted body mass index',
#   'primary_term': True,
#   'vector_term': 'height-adjusted body mass index'}]

# %% [markdown]
# ## term shingles / word ngram

# %%
def shingle(text: str, min_size: int = 2, max_size: int = 4):
    def _shingle(text: str, size: int) -> List[str]:
        tokens = text.split()
        return [' '.join(tokens[i:i+size])
                         for i in range(len(tokens) - size + 1)]
    token_len = len(text.split())
    if token_len < min_size:
        min_size = token_len
    all_shingles = []
    for size in range(min_size, max_size + 1):
        shingles = _shingle(text, size)
        all_shingles.append(shingles)
    # flatten
    all_shingles = list(set([__ for _ in all_shingles for __ in _]))
    return all_shingles

text_list = ["body mass index", "mass", "mass index"]
for idx, text in enumerate(text_list):
    res = shingle(text)
    print(f"#{idx} {text}")
    print(res)
    print("\n")
# Out:
# #0 body mass index
# ['body mass index', 'body mass', 'mass index']
#
#
# #1 mass
# ['mass']
#
#
# #2 mass index
# ['mass index']

# %%
def query_shingles(term_list: List[str], score_threshold=0.9) -> List[Dict[str, Any]]:
    shingle_list = py_.flatten([shingle(_) for _ in term_list])
    query_res = query_equivalence(shingle_list, score_threshold=score_threshold)
    return query_res

def query_equivalence_and_shingles(term_list: List[str], score_threshold=0.9) -> List[Dict[str, Any]]:
    shingle_list = py_.flatten([shingle(_) for _ in term_list])
    shingle_res = query_equivalence(shingle_list, score_threshold=score_threshold)
    equivalence_res = query_equivalence(term_list, score_threshold=score_threshold)
    full_res = py_.chain(shingle_res + equivalence_res) \
        .flatten().uniq_by(lambda e: e["ent_id"]) \
        .value()
    return full_res

# %%
test_terms = [
    ["Intestinal infection"],
    ["Bacterial enteritis"],
    ["Body mass index"],
]

for idx, _ in enumerate(test_terms):
    print(f"# {idx}, {_}")
    search_res = query_equivalence_and_shingles(_)
    pprint(search_res)
    print("\n")
# Out:
# # 0, ['Intestinal infection']
# []
#
#
# # 1, ['Bacterial enteritis']
# [{'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0000916',
#   'ent_term': 'intestinal infectious disease',
#   'primary_term': False,
#   'vector_term': 'bacterial enteritis'},
#  {'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0043579',
#   'ent_term': 'enteritis',
#   'primary_term': True,
#   'vector_term': 'enteritis'}]
#
#
# # 2, ['Body mass index']
# [{'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0013267',
#   'ent_term': 'distal 16p11.2 microdeletion syndrome',
#   'primary_term': False,
#   'vector_term': 'body mass index QTL16'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004340',
#   'ent_term': 'body mass index',
#   'primary_term': True,
#   'vector_term': 'body mass index'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0000790',
#   'ent_term': 'obsolete_adipose tissue',
#   'primary_term': False,
#   'vector_term': 'Body Fat'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0005851',
#   'ent_term': 'height-adjusted body mass index',
#   'primary_term': True,
#   'vector_term': 'height-adjusted body mass index'}]

# %% [markdown]
# ## plain vanilla full text retrieval

# %%
def query_equivalence_fulltext(term_list: List[str]) -> List[Dict[str, Any]]:
    def _query(term: str): 
        es_url = settings.es_url
        index_name = "efo-vectors"
        url = f"{es_url}/{index_name}/_search"
        payload = {
            "query": {
              "match": {
                  "vector_term": {
                      "query": term
                  }
              }
            },
            "_source": ["ent_id", "ent_term", "primary_term", "vector_term"],
        }
        r = requests.get(url, json=payload)
        r.raise_for_status()
        results = [_ for _ in r.json()["hits"]["hits"]]
        return results
    nested_res = [_query(_) for _ in term_list]
    flat_res = py_.chain(nested_res) \
        .flatten() \
        .uniq_by(lambda e: e["_source"]["ent_id"]) \
        .map(lambda e: e["_source"]) \
        .value()
    return flat_res

# %%
test_terms = [
    ["Intestinal infection"],
    ["Bacterial enteritis"],
    ["Body mass index"],
]

for idx, _ in enumerate(test_terms):
    print(f"# {idx}, {_}")
    search_res = query_equivalence_fulltext(_)
    pprint(search_res)
    print("\n")
# Out:
# # 0, ['Intestinal infection']
# [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0007231',
#   'ent_term': 'cysticercosis',
#   'primary_term': False,
#   'vector_term': 'intestinal taenia solium infection'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0007230',
#   'ent_term': 'cyclosporiasis',
#   'primary_term': False,
#   'vector_term': 'intestinal infection caused by Cyclospora cayetanensis'},
#  {'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0024271',
#   'ent_term': 'intestinal helminthiasis',
#   'primary_term': True,
#   'vector_term': 'intestinal helminthiasis'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0002576',
#   'ent_term': 'intestinal endoderm',
#   'primary_term': True,
#   'vector_term': 'intestinal endoderm'},
#  {'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0018178',
#   'ent_term': 'intestinal lymphangiectasia',
#   'primary_term': True,
#   'vector_term': 'intestinal lymphangiectasia'},
#  {'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0008666',
#   'ent_term': 'volvulus of midgut',
#   'primary_term': False,
#   'vector_term': 'intestinal malrotation'},
#  {'ent_id': 'http://purl.obolibrary.org/obo/UBERON_2001076',
#   'ent_term': 'intestinal bulb',
#   'primary_term': True,
#   'vector_term': 'intestinal bulb'}]
#
#
# # 1, ['Bacterial enteritis']
# [{'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0000916',
#   'ent_term': 'intestinal infectious disease',
#   'primary_term': False,
#   'vector_term': 'bacterial enteritis'},
#  {'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0043579',
#   'ent_term': 'enteritis',
#   'primary_term': True,
#   'vector_term': 'enteritis'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0000384',
#   'ent_term': "Crohn's disease",
#   'primary_term': False,
#   'vector_term': 'Enteritis, Granulomatous'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_1001272',
#   'ent_term': 'bacterial pneumonia',
#   'primary_term': True,
#   'vector_term': 'bacterial pneumonia'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_1001351',
#   'ent_term': 'infectious arthritis',
#   'primary_term': False,
#   'vector_term': 'Arthritides, Bacterial'}]
#
#
# # 2, ['Body mass index']
# [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004340',
#   'ent_term': 'body mass index',
#   'primary_term': True,
#   'vector_term': 'body mass index'},
#  {'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0013267',
#   'ent_term': 'distal 16p11.2 microdeletion syndrome',
#   'primary_term': False,
#   'vector_term': 'body mass index QTL16'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0005851',
#   'ent_term': 'height-adjusted body mass index',
#   'primary_term': True,
#   'vector_term': 'height-adjusted body mass index'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0005935',
#   'ent_term': 'overweight body mass index status',
#   'primary_term': True,
#   'vector_term': 'overweight body mass index status'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0005936',
#   'ent_term': 'underweight body mass index status',
#   'primary_term': True,
#   'vector_term': 'underweight body mass index status'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0005937',
#   'ent_term': 'longitudinal BMI measurement',
#   'primary_term': False,
#   'vector_term': 'body mass index change measurement'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0007041',
#   'ent_term': 'obese body mass index status',
#   'primary_term': True,
#   'vector_term': 'obese body mass index status'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0009290',
#   'ent_term': 'left ventricular mass index',
#   'primary_term': False,
#   'vector_term': 'LV mass index'},
#  {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004995',
#   'ent_term': 'lean body mass',
#   'primary_term': True,
#   'vector_term': 'lean body mass'}]

# %% [markdown]
# ## Ontology distance classifier

# %%
def query_distance(
    main_term_list: str, 
    compare_term_list: List[str], 
    distance_threshold: float = 1.5
) -> List[str]:
    def _query(term: str, term_list: List[str], distance_threshold: float) -> List[str]:
        url = "http://ieu-mrbssd1.epi.bris.ac.uk:28015/ontology/distance"
        text_1 = [term] * len(term_list)
        text_2 = term_list
        payload = {
            "text_1": text_1,
            "text_2": text_2,
        }
        r = requests.post(url, json=payload)
        r.raise_for_status()
        search_res = r.json()
        valid_res = [_ for idx, _ in enumerate(term_list) if search_res[idx] <= distance_threshold]
        return valid_res
    if len(compare_term_list) == 0:
        return []
    nested_res = [_query(_, compare_term_list, distance_threshold) for _ in main_term_list]
    flat_res = py_.chain(nested_res) \
        .flatten() \
        .uniq().value()
    return flat_res

# %%
test_terms = [
    ["Intestinal infection"],
    ["Bacterial enteritis"],
    ["Body mass index"],
]

for idx, _ in enumerate(test_terms):
    print(f"# {idx}, {_}")
    equivalence_res = query_equivalence_embeddings(_)
    print(equivalence_res)
    distance_res = query_distance(
        main_term_list=_,
        compare_term_list=[_["vector_term"] for _ in equivalence_res]
    )
    print(distance_res)
    print("\n")
# Out:
# # 0, ['Intestinal infection']
# []
# []
#
#
# # 1, ['Bacterial enteritis']
# [{'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0000916', 'ent_term': 'intestinal infectious disease', 'vector_term': 'bacterial enteritis', 'primary_term': False}, {'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0043579', 'ent_term': 'enteritis', 'vector_term': 'enteritis', 'primary_term': True}]
# ['bacterial enteritis', 'enteritis']
#
#
# # 2, ['Body mass index']
# [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004340', 'ent_term': 'body mass index', 'vector_term': 'body mass index', 'primary_term': True}, {'ent_id': 'http://purl.obolibrary.org/obo/MONDO_0013267', 'ent_term': 'distal 16p11.2 microdeletion syndrome', 'vector_term': 'body mass index QTL16', 'primary_term': False}, {'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0005851', 'ent_term': 'height-adjusted body mass index', 'vector_term': 'height-adjusted body mass index', 'primary_term': True}]
# ['body mass index']

# %% [markdown]
# # Other utils

# %%
main_term = "Body mass index"
term_list = [
    "body mass index",
    "Body Fat",
    "body mass index QTL16",
    "height-adjusted body mass index",
]
for idx, term in enumerate(term_list):
    dist = levenshtein_distance(main_term.lower(), term.lower())
    print(f"# {idx} {term}")
    print(dist)
    print("\n")
# Out:
# # 0 body mass index
# 0
#
#
# # 1 Body Fat
# 9
#
#
# # 2 body mass index QTL16
# 6
#
#
# # 3 height-adjusted body mass index
# 16

# %%
def unpick_obsolete(items: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    res = [
        _ for _ in items if not _["ent_term"].startswith("obsolete_")
    ]
    return res

def pick_perfect_match(term: str, items: List[Dict[str, Any]], score_threshold: int = 0) -> List[Dict[str, Any]]:
    compare_terms = [_["vector_term"] for _ in items]
    dist_list = [levenshtein_distance(term.lower(), _.lower()) for _ in compare_terms]
    valid_items = [
        _
        for idx, _ in enumerate(items)
        if dist_list[idx] <= score_threshold
    ]
    return valid_items

# %% [markdown]
# # actual processing

# %% [markdown]
# ## stage 0 composite mapping

# %%
df_composite = input_df \
    .assign(
      query_res = lambda df: 
        [
            unpick_obsolete(query_composite(_)) 
            for _ in tqdm(df["trait_term_query"], total=len(df))
        ]
    ) \
    .assign(
        perfect_match = lambda df: df.apply(
            # NOTE: trait_term_query is a list
            lambda row: py_.flatten([
                pick_perfect_match(_, row["query_res"]) 
                for _ in row["trait_term_query"]
            ]),
            axis=1
        )
    )

df_composite.info()
df_composite
# Out:
#   0%|                                                                 | 0/2079 [00:00<?, ?it/s]
#   1%|▎                                                      | 14/2079 [00:00<00:14, 138.64it/s]
#   1%|▋                                                      | 28/2079 [00:00<00:16, 122.34it/s]
#   2%|█                                                      | 41/2079 [00:00<00:17, 115.66it/s]
#   3%|█▍                                                     | 54/2079 [00:00<00:16, 119.19it/s]
#   3%|█▊                                                     | 68/2079 [00:00<00:16, 124.77it/s]
#   4%|██▏                                                    | 81/2079 [00:00<00:18, 109.61it/s]
#   4%|██▌                                                     | 93/2079 [00:00<00:22, 90.06it/s]
#   5%|██▊                                                    | 104/2079 [00:00<00:21, 93.86it/s]
#   5%|███                                                    | 114/2079 [00:01<00:21, 93.09it/s]
#   6%|███▎                                                   | 124/2079 [00:01<00:21, 90.56it/s]
#   6%|███▌                                                   | 134/2079 [00:01<00:22, 87.04it/s]
#   7%|███▊                                                   | 143/2079 [00:01<00:22, 86.95it/s]
#   7%|████                                                   | 152/2079 [00:01<00:22, 84.66it/s]
#   8%|████▍                                                  | 166/2079 [00:01<00:19, 98.50it/s]
#   9%|████▋                                                  | 177/2079 [00:01<00:19, 99.49it/s]
#   9%|████▉                                                  | 188/2079 [00:01<00:19, 97.55it/s]
#  10%|█████▏                                                 | 198/2079 [00:02<00:21, 87.07it/s]
#  10%|█████▍                                                 | 207/2079 [00:02<00:23, 80.53it/s]
#  11%|█████▊                                                 | 221/2079 [00:02<00:19, 95.42it/s]
#  11%|██████▏                                               | 236/2079 [00:02<00:17, 107.95it/s]
#  12%|██████▍                                               | 248/2079 [00:02<00:17, 104.35it/s]
#  97%|███████████████████████████████████████████████████▍ | 2016/2079 [00:18<00:00, 100.23it/s]
#  97%|████████████████████████████████████████████████████▋ | 2027/2079 [00:18<00:00, 95.65it/s]
#  98%|████████████████████████████████████████████████████▉ | 2038/2079 [00:19<00:00, 96.84it/s]
#  99%|████████████████████████████████████████████████████▎| 2050/2079 [00:19<00:00, 101.86it/s]
#  99%|█████████████████████████████████████████████████████▌| 2061/2079 [00:19<00:00, 94.60it/s]
# 100%|█████████████████████████████████████████████████████| 2079/2079 [00:19<00:00, 106.49it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2079 entries, 0 to 2078
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   trait_id          2079 non-null   object
#  1   trait_term        2079 non-null   object
#  2   phenotype         2079 non-null   object
#  3   dataset           2079 non-null   object
#  4   trait_type        2079 non-null   object
#  5   trait_term_query  2079 non-null   object
#  6   query_res         2079 non-null   object
#  7   perfect_match     2079 non-null   object
# dtypes: object(8)
# memory usage: 130.1+ KB
#                         trait_id                                trait_term  \
# 0                           8-00                      Intestinal infection
# 1                          85-01                       Bacterial enteritis
# 2                         851-02                         Intestinal e.coli
# 3                         852-03  Intestinal infection due to C. difficile
# 4                          86-04                           Viral Enteritis
# ...                          ...                                       ...
# 2074      dbp-at-enrollment-2076                  Diastolic blood pressure
# 2075  p-pulse-at-enrollment-2077                                Heart rate
# 2076              height-in-2078                                    Heigth
# 2077              weight-lb-2079                                    Weight
# 2078                    bmi-2080                           Body Mass Index
#
#                     phenotype   dataset    trait_type  \
# 0                           8  UKBB+MVP       phecode
# 1                         8.5  UKBB+MVP       phecode
# 2                        8.51       MVP       phecode
# 3                        8.52  UKBB+MVP       phecode
# 4                         8.6  UKBB+MVP       phecode
# ...                       ...       ...           ...
# 2074      DBP (at enrollment)  UKBB+MVP  vital status
# 2075  P (Pulse at enrollment)  UKBB+MVP  vital status
# 2076              Height (in)       MVP  vital status
# 2077              Weight (lb)  UKBB+MVP  vital status
# 2078                      BMI  UKBB+MVP  vital status
#
#                                 trait_term_query  \
# 0                         [Intestinal infection]
# 1                          [Bacterial enteritis]
# 2                            [Intestinal e.coli]
# 3     [Intestinal infection due to C. difficile]
# 4                              [Viral Enteritis]
# ...                                          ...
# 2074                  [Diastolic blood pressure]
# 2075                                [Heart rate]
# 2076                                    [Heigth]
# 2077                                    [Weight]
# 2078                           [Body Mass Index]
#
#                                               query_res  \
# 0     [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0005...
# 1     [{'ent_id': 'http://purl.obolibrary.org/obo/MO...
# 2                                                    []
# 3     [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0005...
# 4     [{'ent_id': 'http://purl.obolibrary.org/obo/MO...
# ...                                                 ...
# 2074  [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0006...
# 2075  [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004...
# 2076                                                 []
# 2077  [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004...
# 2078  [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004...
#
#                                           perfect_match
# 0                                                    []
# 1     [{'ent_id': 'http://purl.obolibrary.org/obo/MO...
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 2074  [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0006...
# 2075  [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004...
# 2076                                                 []
# 2077  [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004...
# 2078  [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004...
#
# [2079 rows x 8 columns]

# %%
output_path = proj_root / "data" / "output" / "composite.json"
assert output_path.parent.exists(), output_path

with output_path.open("w") as f:
    json.dump(df_composite.to_dict(orient="records"), f)
    

output_path = proj_root / "data" / "output" / "perfect.json"
with output_path.open("w") as f:
    json.dump(
        df_composite[
            df_composite["perfect_match"].apply(lambda e: len(e) > 0)].to_dict(orient="records"), 
    f)

# %%
df_composite \
    .assign(retrieval=lambda df: df["query_res"].apply(lambda e: len(e) > 0),
            perfect=lambda df: df["perfect_match"].apply(lambda e: len(e) > 0)) \
    .value_counts(["retrieval", "perfect"])
# Out:
# retrieval  perfect
# True       False      1375
#            True        501
# False      False       203
# dtype: int64

# %% [markdown]
# ## stage 1 embedding mapping

# %%
df_embeddings = df_composite[
    df_composite["perfect_match"].apply(lambda e: len(e) == 0)] \
    .drop(columns=["perfect_match"]) \
    .rename(columns={"query_res": "composite_res"}) \
    .assign(
        embedding_res = lambda df:
        [
            unpick_obsolete(query_equivalence_and_shingles(_))
            for _ in tqdm(df["trait_term_query"], total=len(df))
        ]
    )

df_embeddings.info()
df_embeddings
# Out:
#   0%|                                                                 | 0/1578 [00:00<?, ?it/s]
#   0%|                                                         | 3/1578 [00:00<02:17, 11.46it/s]
#   0%|▏                                                        | 5/1578 [00:00<02:24, 10.85it/s]
#   0%|▎                                                        | 7/1578 [00:00<02:28, 10.56it/s]
#   1%|▎                                                        | 9/1578 [00:00<02:11, 11.89it/s]
#   1%|▍                                                       | 12/1578 [00:00<01:59, 13.08it/s]
#   1%|▍                                                       | 14/1578 [00:01<01:58, 13.25it/s]
#   1%|▌                                                       | 17/1578 [00:01<01:37, 15.98it/s]
#   1%|▋                                                       | 19/1578 [00:01<01:42, 15.28it/s]
#   1%|▋                                                       | 21/1578 [00:01<02:04, 12.46it/s]
#   1%|▊                                                       | 23/1578 [00:01<01:58, 13.11it/s]
#   2%|▉                                                       | 25/1578 [00:01<01:48, 14.34it/s]
#   2%|▉                                                       | 27/1578 [00:02<02:22, 10.90it/s]
#   2%|█                                                       | 31/1578 [00:02<01:40, 15.38it/s]
#   2%|█▏                                                      | 33/1578 [00:02<02:29, 10.30it/s]
#   2%|█▏                                                      | 35/1578 [00:02<02:16, 11.31it/s]
#   2%|█▎                                                      | 37/1578 [00:03<02:41,  9.55it/s]
#   2%|█▍                                                      | 39/1578 [00:03<02:47,  9.19it/s]
#   3%|█▍                                                      | 41/1578 [00:03<02:22, 10.79it/s]
#   3%|█▌                                                      | 43/1578 [00:03<02:14, 11.41it/s]
#   3%|█▌                                                      | 45/1578 [00:03<02:22, 10.78it/s]
#   3%|█▋                                                      | 47/1578 [00:03<02:16, 11.21it/s]
#   3%|█▋                                                      | 49/1578 [00:04<02:11, 11.65it/s]
#   3%|█▊                                                      | 52/1578 [00:04<02:06, 12.02it/s]
#  15%|████████▏                                            | 255/1647 [33:25<3:02:29,  7.87s/it]
#
#   4%|█▉                                                      | 56/1578 [00:05<03:56,  6.43it/s]
#   4%|██                                                      | 58/1578 [00:05<04:26,  5.71it/s]
#   4%|██                                                      | 59/1578 [00:05<04:25,  5.72it/s]
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   trait_id          1578 non-null   object
#  1   trait_term        1578 non-null   object
#  2   phenotype         1578 non-null   object
#  3   dataset           1578 non-null   object
#  4   trait_type        1578 non-null   object
#  5   trait_term_query  1578 non-null   object
#  6   composite_res     1578 non-null   object
#  7   embedding_res     1578 non-null   object
# dtypes: object(8)
# memory usage: 111.0+ KB
#                trait_id                                         trait_term  \
# 0                  8-00                               Intestinal infection
# 2                851-02                                  Intestinal e.coli
# 3                852-03           Intestinal infection due to C. difficile
# 4                 86-04                                    Viral Enteritis
# 5                 87-05               Intestinal infection due to protozoa
# ...                 ...                                                ...
# 2069   fbrthozfrst-2071  What was the birth weight of your first child?...
# 2070  fbrthagefrst-2072    How old were you when you had your first child?
# 2071   fbrthagelst-2073     How old were you when you had your last child?
# 2072     fbrstfeed-2074  Did  you breastfeed your child/children for at...
# 2076     height-in-2078                                             Heigth
#
#          phenotype   dataset        trait_type  \
# 0                8  UKBB+MVP           phecode
# 2             8.51       MVP           phecode
# 3             8.52  UKBB+MVP           phecode
# 4              8.6  UKBB+MVP           phecode
# 5              8.7       MVP           phecode
# ...            ...       ...               ...
# 2069   FBrthOzFrst       MVP  lifestyle_survey
# 2070  FBrthAgeFrst  UKBB+MVP  lifestyle_survey
# 2071   FBrthAgeLst  UKBB+MVP  lifestyle_survey
# 2072     FBrstFeed       MVP  lifestyle_survey
# 2076   Height (in)       MVP      vital status
#
#                                        trait_term_query  \
# 0                                [Intestinal infection]
# 2                                   [Intestinal e.coli]
# 3            [Intestinal infection due to C. difficile]
# 4                                     [Viral Enteritis]
# 5                [Intestinal infection due to protozoa]
# ...                                                 ...
# 2069  [What was the birth weight of your first child...
# 2070  [How old were you when you had your first child ]
# 2071   [How old were you when you had your last child ]
# 2072  [Did  you breastfeed your child children for a...
# 2076                                           [Heigth]
#
#                                           composite_res  \
# 0     [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0005...
# 2                                                    []
# 3     [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0005...
# 4     [{'ent_id': 'http://purl.obolibrary.org/obo/MO...
# 5     [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0005...
# ...                                                 ...
# 2069  [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004...
# 2070  [{'ent_id': 'http://purl.obolibrary.org/obo/MO...
# 2071  [{'ent_id': 'http://purl.obolibrary.org/obo/MO...
# 2072  [{'ent_id': 'http://purl.obolibrary.org/obo/UO...
# 2076                                                 []
#
#                                           embedding_res
# 0                                                    []
# 2     [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_1000...
# 3     [{'ent_id': 'http://purl.obolibrary.org/obo/NC...
# 4     [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_1001...
# 5     [{'ent_id': 'http://purl.obolibrary.org/obo/MO...
# ...                                                 ...
# 2069  [{'ent_id': 'http://www.ebi.ac.uk/efo/EFO_0004...
# 2070                                                 []
# 2071                                                 []
# 2072  [{'ent_id': 'http://purl.obolibrary.org/obo/UO...
# 2076                                                 []
#
# [1578 rows x 8 columns]

# %%
output_path = proj_root / "data" / "output" / "embeddings.json"
assert output_path.parent.exists(), output_path

with output_path.open("w") as f:
    json.dump(df_embeddings.to_dict(orient="records"), f)
    
output_path = proj_root / "data" / "output" / "embeddings.csv"
df_embeddings.to_csv(output_path, index=False)

# %%
df_embeddings \
    .assign(composite=lambda df: df["composite_res"].apply(lambda e: len(e) > 0),
            embeddings=lambda df: df["embedding_res"].apply(lambda e: len(e) > 0)) \
    .value_counts(["composite", "embeddings"])
# Out:
# composite  embeddings
# True       True          1281
# False      True           131
# True       False           94
# False      False           72
# dtype: int64
