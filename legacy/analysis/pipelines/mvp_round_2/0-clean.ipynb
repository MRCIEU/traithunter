# %% [markdown]
# # MVP phenotype terms, round 2, data cleaning

# %% [markdown]
# # Init

# %%
# %load_ext autoreload
# %autoreload 2

# %load_ext lab_black

# %%
import sys
from pathlib import Path

# %%
_pwd = Path(".").resolve()
print(_pwd)
sys.path.append(str(_pwd))
# Out:
# /data/ik18445_cache/projects/phenotype-mapping/analysis/notebooks/mvp_round_2

# %%
from typing import List
import re
import json

import pandas as pd
import janitor
import numpy as np
from pydash import py_

from common_funcs import utils
import mvp_funcs, mvp_types

# %%
proj_root = utils.find_project_root("docker-compose.yml")
assert proj_root.exists(), proj_root

data_path = proj_root / "data"
mvp_terms_path = data_path / "mvp-terms-2022-07" / "all_mapped_phenotypes_03JUN2022.csv"
mvp_terms_1_path = data_path / "mvp-terms-2022-09" / "mvp-terms-2022-09.csv"
assert mvp_terms_path.exists(), mvp_terms_path
assert mvp_terms_1_path.exists(), mvp_terms_1_path

output_path = data_path / "output" / "mvp-mapping-round-2"
output_path.mkdir(exist_ok=True, parents=False)

# %% [markdown]
# # raw datasets

# %%
df_raw = pd.read_csv(mvp_terms_path)
df_raw.info()
df_raw
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2081 entries, 0 to 2080
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Phenotype      2081 non-null   object
#  1   description    2079 non-null   object
#  2   dataset        2081 non-null   object
#  3   MVP_Cases      2060 non-null   object
#  4   MVP_Controls   1977 non-null   float64
#  5   trait_type     2081 non-null   object
#  6   UKBB_filename  1506 non-null   object
#  7   UKBB_Cases     1505 non-null   float64
#  8   UKBB_Controls  1439 non-null   float64
#  9   unmapped_plan  648 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 162.7+ KB
#                     Phenotype                               description  \
# 0                           8                      Intestinal infection
# 1                         8.5                       Bacterial enteritis
# 2                        8.51                         Intestinal e.coli
# 3                        8.52  Intestinal infection due to C. difficile
# 4                         8.6                           Viral Enteritis
# ...                       ...                                       ...
# 2076      DBP (at enrollment)                  Diastolic blood pressure
# 2077  P (Pulse at enrollment)                                Heart rate
# 2078              Height (in)                                    Heigth
# 2079              Weight (lb)                                    Weight
# 2080                      BMI                           Body Mass Index
#
#        dataset MVP_Cases  MVP_Controls    trait_type  \
# 0     UKBB+MVP      9351      454638.0       phecode
# 1     UKBB+MVP      5609      458380.0       phecode
# 2          MVP        57      463932.0       Phecode
# 3     UKBB+MVP      4873      459116.0       phecode
# 4     UKBB+MVP      1347      462642.0       phecode
# ...        ...       ...           ...           ...
# 2076  UKBB+MVP   463,989           NaN  vital status
# 2077  UKBB+MVP   463,989           NaN  vital status
# 2078       MVP   463,989           NaN  vital status
# 2079  UKBB+MVP   463,989           NaN  vital status
# 2080  UKBB+MVP   463,989           NaN  vital status
#
#                                  UKBB_filename  UKBB_Cases  UKBB_Controls  \
# 0               phecode-008-both_sexes.tsv.bgz     13044.0       407487.0
# 1             phecode-008.5-both_sexes.tsv.bgz      3275.0       407487.0
# 2                                          NaN         NaN            NaN
# 3            phecode-008.52-both_sexes.tsv.bgz       858.0       407487.0
# 4             phecode-008.6-both_sexes.tsv.bgz      1114.0       407487.0
# ...                                        ...         ...            ...
# 2076   continuous-4079-both_sexes-irnt.tsv.bgz    396667.0            NaN
# 2077    continuous-102-both_sexes-irnt.tsv.bgz    396667.0            NaN
# 2078                                       NaN         NaN            NaN
# 2079  continuous-21002-both_sexes-irnt.tsv.bgz    419316.0            NaN
# 2080  continuous-21001-both_sexes-irnt.tsv.bgz    419163.0            NaN
#
#      unmapped_plan
# 0              NaN
# 1              NaN
# 2     use MVP only
# 3              NaN
# 4              NaN
# ...            ...
# 2076           NaN
# 2077           NaN
# 2078  use MVP only
# 2079           NaN
# 2080           NaN
#
# [2081 rows x 10 columns]

# %%
df_raw_1 = pd.read_csv(mvp_terms_1_path)
df_raw_1.info()
df_raw_1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3325 entries, 0 to 3324
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   phenocode  3325 non-null   object
#  1   name       3325 non-null   object
#  2   source     3325 non-null   object
# dtypes: object(3)
# memory usage: 78.1+ KB
#                           phenocode  \
# 0                    AB1_AMOEBIASIS
# 1     AB1_ANOGENITAL_HERPES_SIMPLEX
# 2                     AB1_ARTHROPOD
# 3                 AB1_ASPERGILLOSIS
# 4            AB1_ATYPICAL_CNS_VIRUS
# ...                             ...
# 3320          Spinal_canal_stenosis
# 3321                     Mastopathy
# 3322                  Schizophrenia
# 3323                    Tonsillitis
# 3324                  HAV_hepatitis
#
#                                                    name         source
# 0                                            Amoebiasis        FinnGen
# 1     Anogenital herpesviral [herpes simplex] infection        FinnGen
# 2     Arthropod-borne viral fevers and viral haemorr...        FinnGen
# 3                                         Aspergillosis        FinnGen
# 4     Atypical virus infections of central nervous s...        FinnGen
# ...                                                 ...            ...
# 3320                              Spinal canal stenosis  Biobank_Japan
# 3321                                         Mastopathy  Biobank_Japan
# 3322                                      Schizophrenia  Biobank_Japan
# 3323                                        Tonsillitis  Biobank_Japan
# 3324               Acute hepatitis by Hepatitis A virus  Biobank_Japan
#
# [3325 rows x 3 columns]

# %% [markdown]
# # cleaning

# %% [markdown]
# ## pre cleaning diagnostics
#
# - check duplication in id, and id-label combination
# - check id and label emptiness
# - check category counts

# %%
df_raw[df_raw.duplicated(subset=["Phenotype", "description"], keep=False)]
# Out:
# Empty DataFrame
# Columns: [Phenotype, description, dataset, MVP_Cases, MVP_Controls, trait_type, UKBB_filename, UKBB_Cases, UKBB_Controls, unmapped_plan]
# Index: []

# %%
df_raw[df_raw.duplicated(subset=["Phenotype"], keep=False)]
# Out:
#      Phenotype                                        description   dataset  \
# 102     172.11                     C43 Malignant melanoma of skin  UKBB+MVP
# 103     172.11                               D03 Melanoma in situ  UKBB+MVP
# 1290       620      N89 Other noninflammatory disorders of vagina  UKBB+MVP
# 1291       620  N90 Other noninflammatory disorders of vulva a...  UKBB+MVP
# 1859    1010.5                  Z22 Carrier of infectious disease  UKBB+MVP
# 1860    1010.5           Z29 Need for other prophylactic measures  UKBB+MVP
# 1861    1010.6                         Z31 Procreative management  UKBB+MVP
# 1862    1010.6                 Z32 Pregnancy examination and test  UKBB+MVP
# 1863    1010.6                            Z36 Antenatal screening  UKBB+MVP
# 1864    1010.7  Z56 Problems related to employment and unemplo...  UKBB+MVP
# 1865    1010.7          Z57 Occupational exposure to risk-factors  UKBB+MVP
# 1866    1010.7  Z59 Problems related to housing and economic c...  UKBB+MVP
# 1867    1010.7  Z63 Other problems related to primary support ...  UKBB+MVP
# 1868    1010.7  Z71 Persons encountering health services for o...  UKBB+MVP
# 1869    1010.7  Z73 Problems related to life-management diffic...  UKBB+MVP
# 1870    1010.7   Z74 Problems related to care-provider dependency  UKBB+MVP
# 1871    1010.7  Z75 Problems related to medical facilities and...  UKBB+MVP
# 1872    1010.7  Z76 Persons encountering health services in ot...  UKBB+MVP
# 1967    Smk100  In your lifetime, have you smoked a total of a...  UKBB+MVP
# 2040    Smk100  In your lifetime, have you smoked a total of a...  UKBB+MVP
#
#      MVP_Cases  MVP_Controls        trait_type  \
# 102      10578      453411.0             icd10
# 103      10578      453411.0             icd10
# 1290       492      463497.0             icd10
# 1291       492      463497.0             icd10
# 1859    243866      220123.0             icd10
# 1860    243866      220123.0             icd10
# 1861      5167      458822.0             icd10
# 1862      5167      458822.0             icd10
# 1863      5167      458822.0             icd10
# 1864    380882       83107.0             icd10
# 1865    380882       83107.0             icd10
# 1866    380882       83107.0             icd10
# 1867    380882       83107.0             icd10
# 1868    380882       83107.0             icd10
# 1869    380882       83107.0             icd10
# 1870    380882       83107.0             icd10
# 1871    380882       83107.0             icd10
# 1872    380882       83107.0             icd10
# 1967    230114       85749.0   baseline_survey
# 2040    170877       74622.0  lifestyle_survey
#
#                                    UKBB_filename  UKBB_Cases  UKBB_Controls  \
# 102                 icd10-C43-both_sexes.tsv.bgz      2598.0       417933.0
# 103                 icd10-D03-both_sexes.tsv.bgz       956.0       419575.0
# 1290                icd10-N89-both_sexes.tsv.bgz      1692.0       418839.0
# 1291                icd10-N90-both_sexes.tsv.bgz      2175.0       418356.0
# 1859                icd10-Z22-both_sexes.tsv.bgz      1472.0       419059.0
# 1860                icd10-Z29-both_sexes.tsv.bgz       888.0       419643.0
# 1861                icd10-Z31-both_sexes.tsv.bgz       322.0       420209.0
# 1862                icd10-Z32-both_sexes.tsv.bgz       185.0       420346.0
# 1863                icd10-Z36-both_sexes.tsv.bgz      1293.0       419238.0
# 1864                icd10-Z56-both_sexes.tsv.bgz       182.0       420349.0
# 1865                icd10-Z57-both_sexes.tsv.bgz       726.0       419805.0
# 1866                icd10-Z59-both_sexes.tsv.bgz       190.0       420341.0
# 1867                icd10-Z63-both_sexes.tsv.bgz       583.0       419948.0
# 1868                icd10-Z71-both_sexes.tsv.bgz      1570.0       418961.0
# 1869                icd10-Z73-both_sexes.tsv.bgz       891.0       419640.0
# 1870                icd10-Z74-both_sexes.tsv.bgz       596.0       419935.0
# 1871                icd10-Z75-both_sexes.tsv.bgz      1075.0       419456.0
# 1872                icd10-Z76-both_sexes.tsv.bgz       209.0       420322.0
# 1967    categorical-2644-both_sexes-2644.tsv.bgz     51160.0        60829.0
# 2040  categorical-20160-both_sexes-20160.tsv.bgz    253507.0       165353.0
#
#      unmapped_plan
# 102            NaN
# 103            NaN
# 1290           NaN
# 1291           NaN
# 1859           NaN
# 1860           NaN
# 1861           NaN
# 1862           NaN
# 1863           NaN
# 1864           NaN
# 1865           NaN
# 1866           NaN
# 1867           NaN
# 1868           NaN
# 1869           NaN
# 1870           NaN
# 1871           NaN
# 1872           NaN
# 1967           NaN
# 2040           NaN

# %%
df_raw_1[df_raw_1.duplicated(subset=["phenocode", "name"], keep=False)]
# Out:
#      phenocode                       name         source
# 1581       ILD  Interstitial lung disease        FinnGen
# 3202       ILD  Interstitial lung disease  Biobank_Japan

# %%
df_raw_1[df_raw_1.duplicated(subset=["phenocode"], keep=False)]
# Out:
#      phenocode                                   name         source
# 1581       ILD              Interstitial lung disease        FinnGen
# 2945       T1D   Type1 diabetes, definitions combined        FinnGen
# 2952       T2D  Type 2 diabetes, definitions combined        FinnGen
# 3111       T2D                        Type 2 diabetes  Biobank_Japan
# 3202       ILD              Interstitial lung disease  Biobank_Japan
# 3209       T1D                        Type 1 diabetes  Biobank_Japan

# %%
_cols = ["Phenotype", "description", "dataset"]
_df = df_raw
for _col in _cols:
    print(_col)
    _df_slice = _df[(_df[_col].isnull()) | (_df[_col] == "")]
    print(len(_df_slice))

_cols = ["phenocode", "name", "source"]
_df = df_raw_1
for _col in _cols:
    print(_col)
    _df_slice = _df[(_df[_col].isnull()) | (_df[_col] == "")]
    print(len(_df_slice))
# Out:
# Phenotype
# 0
# description
# 2
# dataset
# 0
# phenocode
# 0
# name
# 0
# source
# 0

# %%
df_raw[df_raw["description"].isnull()]
# Out:
#      Phenotype description dataset MVP_Cases  MVP_Controls trait_type  \
# 1942   TotalCK         NaN     MVP    230038           NaN        lab
# 1945  Troponin         NaN     MVP     17905           NaN        lab
#
#      UKBB_filename  UKBB_Cases  UKBB_Controls unmapped_plan
# 1942           NaN         NaN            NaN  use MVP only
# 1945           NaN         NaN            NaN  use MVP only

# %%
print(df_raw["dataset"].value_counts())
print(df_raw_1["source"].value_counts())
# Out:
# UKBB+MVP    1490
# MVP          577
# UKBB          14
# Name: dataset, dtype: int64
# FinnGen          3095
# Biobank_Japan     230
# Name: source, dtype: int64

# %% [markdown]
# ## cleaning
#
# - drop empty items
# - create trait id
# - reshape df into desired format

# %%
df_clean = (
    df_raw.also(lambda df: print("Init", len(df)))[
        ["Phenotype", "description", "dataset"]
    ]
    # drop dupes
    .drop_duplicates()
    .also(lambda df: print("Drop dupes", len(df)))
    # remove empty fields
    .dropna()
    .also(lambda df: print("Drop NA", len(df)))
    # trait id
    .reset_index(drop=True)
    .reset_index(drop=False)
    .assign(
        trait_id=lambda df: df.apply(
            lambda row: "{dataset}-{phenotype}-{index:02d}".format(
                dataset=row["dataset"],
                phenotype=mvp_funcs.clean_phenotype_id(row["Phenotype"]),
                index=row["index"],
            ),
            axis=1,
        )
    )
    .also(lambda df: print("IDs: {ids}".format(ids=df["trait_id"].tolist()[:5])))
    # trait term
    .assign(trait_term=lambda df: df["description"])
    # wrap up
    .assign(
        trait_basic_info=lambda df: df.apply(
            lambda row: {
                "Phenotype": row["Phenotype"],
                "description": row["description"],
                "dataset": row["dataset"],
            },
            axis=1,
        )
    )
    .drop(columns=["index", "Phenotype", "description", "dataset"])
)
df_clean.info()
# Out:
# Init 2081
# Drop dupes 2081
# Drop NA 2079
# IDs: ['UKBB+MVP-8-00', 'UKBB+MVP-85-01', 'MVP-851-02', 'UKBB+MVP-852-03', 'UKBB+MVP-86-04']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2079 entries, 0 to 2078
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   trait_id          2079 non-null   object
#  1   trait_term        2079 non-null   object
#  2   trait_basic_info  2079 non-null   object
# dtypes: object(3)
# memory usage: 48.9+ KB

# %%
df_clean_1 = (
    df_raw_1.also(lambda df: print("Init", len(df)))
    # drop dupes
    .drop_duplicates()
    .also(lambda df: print("Drop dupes", len(df)))
    # remove empty fields
    .dropna()
    .also(lambda df: print("Drop NA", len(df)))
    # trait id
    .reset_index(drop=True)
    .reset_index(drop=False)
    .assign(
        trait_id=lambda df: df.apply(
            lambda row: "{source}-{phenocode}-{index:02d}".format(
                source=row["source"],
                phenocode=row["phenocode"],
                index=row["index"],
            ),
            axis=1,
        )
    )
    .also(lambda df: print("IDs: {ids}".format(ids=df["trait_id"].tolist()[:5])))
    # trait term
    .assign(trait_term=lambda df: df["name"])
    # wrap up
    .assign(
        trait_basic_info=lambda df: df.apply(
            lambda row: {
                "phenocode": row["phenocode"],
                "name": row["name"],
                "source": row["source"],
            },
            axis=1,
        )
    )
    .drop(columns=["index", "phenocode", "name", "source"])
)
df_clean_1.info()
# Out:
# Init 3325
# Drop dupes 3325
# Drop NA 3325
# IDs: ['FinnGen-AB1_AMOEBIASIS-00', 'FinnGen-AB1_ANOGENITAL_HERPES_SIMPLEX-01', 'FinnGen-AB1_ARTHROPOD-02', 'FinnGen-AB1_ASPERGILLOSIS-03', 'FinnGen-AB1_ATYPICAL_CNS_VIRUS-04']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3325 entries, 0 to 3324
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   trait_id          3325 non-null   object
#  1   trait_term        3325 non-null   object
#  2   trait_basic_info  3325 non-null   object
# dtypes: object(3)
# memory usage: 78.1+ KB

# %%
COLS = ["trait_id", "trait_term", "trait_term_clean", "trait_basic_info"]

df_clean_merge = pd.concat([df_clean, df_clean_1]).reset_index(drop=True)
df_clean_merge = df_clean_merge.assign(
    trait_term_clean=lambda df: df["trait_term"].apply(mvp_funcs.clean_trait_term)
)[COLS]
mvp_types.CleanedDf.validate(df_clean_merge)
df_clean_merge.info()
df_clean_merge
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5404 entries, 0 to 5403
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   trait_id          5404 non-null   object
#  1   trait_term        5404 non-null   object
#  2   trait_term_clean  5404 non-null   object
#  3   trait_basic_info  5404 non-null   object
# dtypes: object(4)
# memory usage: 169.0+ KB
#                                       trait_id  \
# 0                                UKBB+MVP-8-00
# 1                               UKBB+MVP-85-01
# 2                                   MVP-851-02
# 3                              UKBB+MVP-852-03
# 4                               UKBB+MVP-86-04
# ...                                        ...
# 5399  Biobank_Japan-Spinal_canal_stenosis-3320
# 5400             Biobank_Japan-Mastopathy-3321
# 5401          Biobank_Japan-Schizophrenia-3322
# 5402            Biobank_Japan-Tonsillitis-3323
# 5403          Biobank_Japan-HAV_hepatitis-3324
#
#                                     trait_term  \
# 0                         Intestinal infection
# 1                          Bacterial enteritis
# 2                            Intestinal e.coli
# 3     Intestinal infection due to C. difficile
# 4                              Viral Enteritis
# ...                                        ...
# 5399                     Spinal canal stenosis
# 5400                                Mastopathy
# 5401                             Schizophrenia
# 5402                               Tonsillitis
# 5403      Acute hepatitis by Hepatitis A virus
#
#                               trait_term_clean  \
# 0                         Intestinal infection
# 1                          Bacterial enteritis
# 2                            Intestinal e.coli
# 3     Intestinal infection due to C. difficile
# 4                              Viral Enteritis
# ...                                        ...
# 5399                     Spinal canal stenosis
# 5400                                Mastopathy
# 5401                             Schizophrenia
# 5402                               Tonsillitis
# 5403      Acute hepatitis by Hepatitis A virus
#
#                                        trait_basic_info
# 0     {'Phenotype': '8', 'description': 'Intestinal ...
# 1     {'Phenotype': '8.5', 'description': 'Bacterial...
# 2     {'Phenotype': '8.51', 'description': 'Intestin...
# 3     {'Phenotype': '8.52', 'description': 'Intestin...
# 4     {'Phenotype': '8.6', 'description': 'Viral Ent...
# ...                                                 ...
# 5399  {'phenocode': 'Spinal_canal_stenosis', 'name':...
# 5400  {'phenocode': 'Mastopathy', 'name': 'Mastopath...
# 5401  {'phenocode': 'Schizophrenia', 'name': 'Schizo...
# 5402  {'phenocode': 'Tonsillitis', 'name': 'Tonsilli...
# 5403  {'phenocode': 'HAV_hepatitis', 'name': 'Acute ...
#
# [5404 rows x 4 columns]

# %% [markdown]
# ## Post cleaning diagnostics
#
# None at the moment

# %% [markdown]
# # wrap up

# %%
output_file = output_path / "mvp-terms-clean.json"
with output_file.open("w") as f:
    json.dump(df_clean_merge.to_dict(orient="records"), f)

# %%
FLAT_COLS = ["trait_id", "trait_term", "trait_term_clean"]

output_file_flat = output_path / "mvp-terms-clean-flat.csv"
df_clean_merge[FLAT_COLS].to_csv(output_file_flat, index=False)
