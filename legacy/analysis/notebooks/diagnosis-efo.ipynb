# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import pandas as pd

from pprint import pprint

from funcs import paths

# %%
efo_path = paths.data["efo"]
assert efo_path.exists(), efo_path

with efo_path.open() as f:
    data = json.load(f)
    
efo = data["graphs"][0]

print(efo.keys())
# Out:
# dict_keys(['nodes', 'edges', 'id', 'meta', 'equivalentNodesSets', 'logicalDefinitionAxioms', 'domainRangeAxioms', 'propertyChainAxioms'])

# %%
efo_nodes = pd.json_normalize(efo["nodes"])
print(efo_nodes.info())
efo_nodes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36180 entries, 0 to 36179
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        36180 non-null  object
#  1   type                      36075 non-null  object
#  2   lbl                       36170 non-null  object
#  3   meta.definition.val       25007 non-null  object
#  4   meta.definition.xrefs     25007 non-null  object
#  5   meta.xrefs                27741 non-null  object
#  6   meta.synonyms             23577 non-null  object
#  7   meta.basicPropertyValues  30196 non-null  object
#  8   meta.subsets              8835 non-null   object
# dtypes: object(9)
# memory usage: 2.5+ MB
# None
#                                                   id   type  \
# 0       http://purl.obolibrary.org/obo/MONDO_0002974  CLASS
# 1          http://www.orpha.net/ORDO/Orphanet_199315  CLASS
# ...

# %%
efo_nodes["type"].value_counts()
# Out:
# CLASS       35958
# PROPERTY      117
# Name: type, dtype: int64

# %%
efo_nodes[efo_nodes["type"] == "PROPERTY"]
# Out:
#                                                       id      type  \
# 356        http://www.w3.org/2004/02/skos/core#prefLabel  PROPERTY
# 969                 http://www.ebi.ac.uk/efo/EFO_0006351  PROPERTY
# 2747     http://purl.obolibrary.org/obo/chebi#BRAND_NAME  PROPERTY
# 2758          http://purl.obolibrary.org/obo/IAO_0100001  PROPERTY
# 3862             http://purl.obolibrary.org/obo#has_role  PROPERTY
# ...                                                  ...       ...
# 34208          http://purl.obolibrary.org/obo/RO_0004029  PROPERTY
# 34223          http://purl.obolibrary.org/obo/RO_0004027  PROPERTY
# 34231          http://purl.obolibrary.org/obo/RO_0004022  PROPERTY
# 34903       http://www.w3.org/2000/01/rdf-schema#seeAlso  PROPERTY
# 35624  http://www.geneontology.org/formats/oboInOwl#i...  PROPERTY
#
#                                  lbl  \
# 356                  preferred label
# 969                     has_about_it
# 2747                      BRAND NAME
# ...

# %%
foo =  efo_nodes[efo_nodes["type"] == "CLASS"].to_dict(orient="records")
pprint(foo[:5])
# Out:
# [{'id': 'http://purl.obolibrary.org/obo/MONDO_0002974',
#   'lbl': 'cervical cancer',
#   'meta.basicPropertyValues': [{'pred': 'http://purl.obolibrary.org/obo/mondo#exactMatch',
#                                 'val': 'http://purl.obolibrary.org/obo/NCIT_C9311'},
#                                {'pred': 'http://purl.obolibrary.org/obo/mondo#exactMatch',
#                                 'val': 'http://purl.obolibrary.org/obo/DOID_4362'},
#                                {'pred': 'http://www.w3.org/2000/01/rdf-schema#seeAlso',
#                                 'val': 'https://github.com/monarch-initiative/mondo/issues/4521'},
#                                {'pred': 'http://purl.obolibrary.org/obo/mondo#exactMatch',
#                                 'val': 'https://omim.org/entry/603956'},
#                                {'pred': 'http://purl.obolibrary.org/obo/mondo#exactMatch',
#                                 'val': 'http://identifiers.org/snomedct/363354003'},
# ...
